# %% [markdown]
# Creación de una base de datos en Railway.com
# - https://railway.com/
# - 🛠️ La aplicación Railway ofrece una solución sencilla para implementar bases de datos MySQL sin instalación.
# - 🔑 Se puede acceder fácilmente a las variables de conexión para la integración con clientes de bases de datos.

# %%
# !pip install mysql-connector-python
# !pip install pymysql

# %%
import pandas as pd

# %% [markdown]
# # Creamos la conexión a la base de datos de railway

# %%
import mysql.connector

# %%
# mysql://root:sQGJOjroYvDHdacUUcfqgwnuYrsFqkbv@viaduct.proxy.rlwy.net:17016/railway
# Configuración de la conexión usando el host público

config = {
    'user': 'root',
    'password': 'mgTFibCsvHYiygGxrLrReVyyqYJhAXAc',
    'host': 'tramway.proxy.rlwy.net',
    'database': 'railway',
    'port': 55610
}

try:
    connection = mysql.connector.connect(**config)
    cursor = connection.cursor()
    cursor.execute("SELECT 1")
    result = cursor.fetchone()
    print("Resultado:", result)
except Exception as err:
    print("Error:", err)
finally:
    try:
        cursor.close()
        connection.close()
    except Exception:
        pass
# Out:
# Resultado: (1,)

# %% [markdown]
# # Creamos una función que se conecte a la Base de Datos, ejecute el código SQL y cierre la conexión

# %%
def ejecutor_sql(codigo_sql):
    import mysql.connector
    # Configuración de la conexión usando el host público
    config = {
        'user': 'root',
        'password': 'mgTFibCsvHYiygGxrLrReVyyqYJhAXAc',
        'host': 'tramway.proxy.rlwy.net',
        'database': 'railway',
        'port': 55610
}
    
    connection = None  # Inicializamos la variable para evitar errores en el finally
    try:
        connection = mysql.connector.connect(**config)
        cursor = connection.cursor()

        # Ejecutar el código SQL
        cursor.execute(codigo_sql)
        connection.commit()
        print("✅ Ejecución correcta de SQL")

    except mysql.connector.Error as e:
        print(f"❌ Error de MySQL: {e}")

    finally:
        if connection:
            cursor.close()
            connection.close()
            print("🔗 Conexión cerrada")

# %% [markdown]
# ## Creación de la base de datos

# %%
# Crear una base de datos
create_table_query = """
CREATE DATABASE videoclub;
USE videoclub;
"""
ejecutor_sql(create_table_query)
# Out:
# ❌ Error de MySQL: 1007 (HY000): Can't create database 'videoclub'; database exists
# 🔗 Conexión cerrada

# %% [markdown]
# # Inserción de la tabla de ciudades

# %%
# Crear una tabla
create_table_query = """
-- Tabla Ciudades
CREATE TABLE Ciudades (
ciudad_id INT AUTO_INCREMENT PRIMARY KEY,
nombre VARCHAR(100) NOT NULL,
provincia VARCHAR(30),
comunidad VARCHAR(30),
cod_postal VARCHAR(5),
latitud DECIMAL(11, 8),
longitud DECIMAL(11, 8)
);
"""
ejecutor_sql(create_table_query)
# Out:
# ❌ Error de MySQL: 1050 (42S01): Table 'Ciudades' already exists
# 🔗 Conexión cerrada

# %%
# Eliminar una tabla
delete_table_query = """
-- Tabla Ciudades
DROP TABLE Ciudades;
"""
# ejecutor_sql(delete_table_query)

# %% [markdown]
# ## Vamos a añadir todos los municipios de España a Ciudades

# %%
#municipios_espana = pd.read_excel("https://www.businessintelligence.info/resources/assets/listado-longitud-latitud-municipios-espana.xls", skiprows=2)
municipios_espana = pd.read_excel(r"C:\americo\entorno_virtual\listado-longitud-latitud-municipios-espana.xls", skiprows=2)

# %%
# Como añadirlos todos tarda más de 15 minutos, selecciono sólo los de Euskadi
municipios_espana = municipios_espana[municipios_espana['Comunidad'] == 'País Vasco']

# %%
municipios_espana.head()
# Out:
#        Comunidad Provincia         Población   Latitud  Longitud   Altitud  \
# 7319  País Vasco     Álava  Alegría-Dulantzi  42.84149 -2.513507  561.6857
# 7320  País Vasco     Álava           Amurrio  43.05265 -3.001022  219.6910
# 7321  País Vasco     Álava             Añana  42.80235 -2.982607  628.5115
# 7322  País Vasco     Álava           Aramaio  43.05400 -2.566000  381.8797
# 7323  País Vasco     Álava           Armiñón  42.72305 -2.872574  463.5815
#
#       Habitantes  Hombres  Mujeres
# 7319        2620     1353     1267
# 7320       10089     5069     5020
# 7321         176       92       84
# 7322        1499      781      718
# 7323         207      103      104

# %%
cp = pd.read_csv("https://github.com/inigoflores/ds-codigos-postales-ine-es/raw/refs/heads/master/data/codigos_postales_municipios.csv")
cp.head()
# Out:
#    codigo_postal  municipio_id        municipio_nombre
# 0             43         43110  Pobla de Massaluca, La
# 1             85         49064                  Fariza
# 2            633         26005       Albelda de Iregua
# 3           1001          1059         Vitoria-Gasteiz
# 4           1002          1059         Vitoria-Gasteiz

# %%
municipios_espana = municipios_espana.merge(cp, left_on='Población', right_on='municipio_nombre')
municipios_espana.head()
# Out:
#     Comunidad Provincia         Población   Latitud  Longitud   Altitud  \
# 0  País Vasco     Álava  Alegría-Dulantzi  42.84149 -2.513507  561.6857
# 1  País Vasco     Álava  Alegría-Dulantzi  42.84149 -2.513507  561.6857
# 2  País Vasco     Álava           Amurrio  43.05265 -3.001022  219.6910
# 3  País Vasco     Álava           Amurrio  43.05265 -3.001022  219.6910
# 4  País Vasco     Álava           Amurrio  43.05265 -3.001022  219.6910
#
#    Habitantes  Hombres  Mujeres  codigo_postal  municipio_id  municipio_nombre
# 0        2620     1353     1267           1193          1001  Alegría-Dulantzi
# 1        2620     1353     1267           1240          1001  Alegría-Dulantzi
# 2       10089     5069     5020           1450          1002           Amurrio
# 3       10089     5069     5020           1468          1002           Amurrio
# 4       10089     5069     5020           1470          1002           Amurrio

# %%
municipios_espana.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Comunidad         389 non-null    object
#  1   Provincia         389 non-null    object
#  2   Población         389 non-null    object
#  3   Latitud           389 non-null    float64
#  4   Longitud          389 non-null    float64
#  5   Altitud           389 non-null    float64
#  6   Habitantes        389 non-null    int64
#  7   Hombres           389 non-null    int64
#  8   Mujeres           389 non-null    int64
#  9   codigo_postal     389 non-null    int64
#  10  municipio_id      389 non-null    int64
#  11  municipio_nombre  389 non-null    object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 36.6+ KB

# %% [markdown]
# Esta función irá añadiendo a la base de datos cada municipio, recibiendo los datos como parámetro

# %%
# Insertar datos de ciudades
def insertar_ciudades(values):
    insert_query = f"""INSERT INTO Ciudades (nombre, provincia, comunidad, cod_postal, latitud, longitud)
    VALUES ('{values[0]}', '{values[1]}', '{values[2]}', '{values[3]}', {values[4]}, {values[5]});"""
    ejecutor_sql(insert_query)  # Es importante hacer commit para guardar los cambios
    print(f"{values[0]} insertado exitosamente")

# %% [markdown]
# Voy extrayendo los datos en formato tupla de cada fila del DataFrame y haciendo la inserción.

# %%
for index, row in municipios_espana.iterrows():
    nombre = row['Población']
    provincia = row['Provincia']
    comunidad = row['Comunidad']
    cod_postal = row['codigo_postal']
    latitud = row['Latitud']
    longitud = row['Longitud']
    values = (nombre, provincia, comunidad, cod_postal, latitud, longitud)
    insertar_ciudades(values)
# Out:
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Alegría-Dulantzi insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Alegría-Dulantzi insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Amurrio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Amurrio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Amurrio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Añana insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Añana insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Aramaio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Aramaio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Aramaio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Armiñón insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Armiñón insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arraia-Maeztu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arraia-Maeztu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arraia-Maeztu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Artziniega insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Artziniega insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Asparrena insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Asparrena insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Asparrena insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ayala/Aiara insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ayala/Aiara insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ayala/Aiara insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ayala/Aiara insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ayala/Aiara insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ayala/Aiara insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Baños de Ebro/Mañueta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Barrundia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Barrundia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Berantevilla insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Berantevilla insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Berantevilla insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Berantevilla insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bernedo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bernedo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bernedo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bernedo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Campezo/Kanpezu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Campezo/Kanpezu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Campezo/Kanpezu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Elburgo/Burgelu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Elburgo/Burgelu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Elciego insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Elvillar/Bilar insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Erriberagoitia/Ribera Alta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Erriberagoitia/Ribera Alta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Erriberagoitia/Ribera Alta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Erriberagoitia/Ribera Alta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Erriberagoitia/Ribera Alta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Erriberagoitia/Ribera Alta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Harana/Valle de Arana insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Iruña Oka/Iruña de Oca insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Iruña Oka/Iruña de Oca insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Iruña Oka/Iruña de Oca insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Iruña Oka/Iruña de Oca insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Iruraiz-Gauna insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Iruraiz-Gauna insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Iruraiz-Gauna insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Kripan insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Kuartango insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Kuartango insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Labastida/Bastida insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Labastida/Bastida insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Labastida/Bastida insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lagrán insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lagrán insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Laguardia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Laguardia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Laguardia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Laguardia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lanciego/Lantziego insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lantarón insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lantarón insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lapuebla de Labarca insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Laudio/Llodio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Leza insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Navaridas insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Okondo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Oyón-Oion insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Oyón-Oion insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Peñacerrada-Urizaharra insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Peñacerrada-Urizaharra insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Peñacerrada-Urizaharra insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ribera Baja/Erribera Beitia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ribera Baja/Erribera Beitia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Samaniego insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# San Millán/Donemiliaga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# San Millán/Donemiliaga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Urkabustaiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Urkabustaiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Urkabustaiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Valdegovía/Gaubea insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Valdegovía/Gaubea insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Valdegovía/Gaubea insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Valdegovía/Gaubea insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Villabuena de Álava/Eskuernaga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Vitoria-Gasteiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Yécora/Iekora insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zalduondo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zambrana insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zigoitia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zigoitia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zuia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zuia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zuia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Abaltzisketa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Aduna insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Aia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Aia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Aizarnazabal insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Albiztur insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Alegia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Alkiza insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Altzaga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Altzo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Amezketa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Andoain insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Anoeta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Antzuola insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arama insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Aretxabaleta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arrasate/Mondragón insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Asteasu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Astigarraga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ataun insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Azkoitia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Azpeitia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Baliarrain insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Beasain insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Beizama insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Belauntza insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Berastegi insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Berastegi insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bergara insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bergara insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bergara insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bergara insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Berrobi insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Deba insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Deba insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Eibar insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Elduain insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Elgeta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Elgoibar insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Elgoibar insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Errenteria insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Errezil insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Eskoriatza insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Eskoriatza insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ezkio-Itsaso insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ezkio-Itsaso insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gabiria insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gaintza insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gaztelu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Getaria insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Hernani insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Hernani insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Hernialde insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Hondarribia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ibarra insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Idiazabal insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ikaztegieta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Irun insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Irun insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Irun insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Irun insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Irun insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Irura insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Itsasondo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Larraul insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lasarte-Oria insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lazkao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Leaburu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Legazpi insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Legazpi insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Legorreta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Leintz-Gatzaga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lezo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lizartza insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Mendaro insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Mutiloa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Mutriku insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Oiartzun insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Olaberria insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Oñati insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Oñati insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Oñati insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Oñati insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ordizia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Orendain insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Orexa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Orio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ormaiztegi insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Pasaia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Segura insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Tolosa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Tolosa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Tolosa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Tolosa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Urnieta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Urretxu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Usurbil insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Villabona insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zaldibia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zarautz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zegama insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zerain insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zestoa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zestoa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zizurkil insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zumaia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zumarraga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Abadiño insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Abanto y Ciérvana-Abanto Zierbena insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Abanto y Ciérvana-Abanto Zierbena insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ajangiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Alonsotegi insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Amorebieta-Etxano insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Amorebieta-Etxano insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Amoroto insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arakaldo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arantzazu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Areatza insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arrankudiaga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arratzu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arratzu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arratzu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arrieta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arrigorriaga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Arrigorriaga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Artea insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Artzentales insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Atxondo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Atxondo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Aulesti insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bakio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Balmaseda insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Barakaldo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Barakaldo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Barakaldo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Barrika insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Basauri insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bedia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Berango insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bermeo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Berriatua insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Berriz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Berriz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Bilbao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Busturia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Derio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Derio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Dima insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Durango insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ea insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ea insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Elantxobe insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Elorrio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Erandio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Erandio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ereño insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ermua insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Errigoiti insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Etxebarri insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Etxebarria insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Forua insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Fruiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Galdakao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Galdames insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gamiz-Fika insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Garai insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gatika insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gautegiz Arteaga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gernika-Lumo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Getxo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Getxo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Getxo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Getxo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Getxo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gizaburuaga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gordexola insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gordexola insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gorliz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Gorliz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Güeñes insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Güeñes insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Güeñes insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ibarrangelu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Igorre insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ispaster insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Iurreta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Izurtza insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Karrantza Harana/Valle de Carranza insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Karrantza Harana/Valle de Carranza insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Kortezubi insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lanestosa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Larrabetzu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Laukiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Leioa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lekeitio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lemoa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lemoiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Lezama insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Loiu insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Mallabia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Mañaria insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Markina-Xemein insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Markina-Xemein insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Markina-Xemein insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Maruri-Jatabe insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Meñaka insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Mendata insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Mendexa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Morga insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Mundaka insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Mungia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Mungia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Munitibar-Arbatzegi Gerrikaitz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Murueta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Muskiz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Muxika insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Muxika insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Nabarniz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ondarroa insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Orozko insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Orozko insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ortuella insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Otxandio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Plentzia insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Portugalete insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Santurtzi insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Sestao insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Sondika insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Sopuerta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Sopuerta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Sopuerta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Sopuerta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Sukarrieta insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Trucios-Turtzioz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ubide insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ugao-Miraballes insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Urduliz insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Urduña/Orduña insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Valle de Trápaga-Trapagaran insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Valle de Trápaga-Trapagaran insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zaldibar insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zalla insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zalla insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zalla insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zamudio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zaratamo insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zeanuri insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zeberio insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Zierbena insertado exitosamente
# ✅ Ejecución correcta de SQL
# 🔗 Conexión cerrada
# Ziortza-Bolibar insertado exitosamente

# %%
from sqlalchemy import create_engine

# %%
# URL de conexión a la base de datos

def leer_tabla(tabla):
    config = {
        'user': 'root',  # Usuario
        'password': 'sQGJOjroYvDHdacUUcfqgwnuYrsFqkbv',  # Contraseña
        'host': 'viaduct.proxy.rlwy.net',  # Host público de Railway
        'database': 'railway',  # Nombre de la base de datos
        'port': 17016  # Puerto público de Railway
    }
    db_password = config['password']
    db_host = config['host']
    port = config['port']
    db_url = f"mysql+pymysql://root:{db_password}@{db_host}:{port}/railway"

    # Crear una instancia de motor (engine)
    engine = create_engine(db_url)

    # Realizar una conexión a la base de datos
    try:
        # Intentar conectarse a la base de datos
        connection = engine.connect()
        contenido = pd.read_sql(f"SELECT * FROM {tabla}", connection)
    except Exception as e:
        print(f"Error de conexión: {e}")
    finally:
        # Cerrar la conexión cuando hayas terminado
        if connection:
            connection.close()
        return contenido

# %% [markdown]
# # REVISAR ^ARRIBA

# %% [markdown]
# ## Creacion Tipo_cliente

# %%
creacion_tabla = """
    CREATE TABLE Tipos_cliente (
    tipo_cliente_id INT AUTO_INCREMENT PRIMARY KEY,
    clase VARCHAR(1) NOT NULL,
    tasa DECIMAL(4, 2),
    num_prestamos INT,
    dias_max_prestamo INT
    );"""
insercion_datos = """
    INSERT INTO Tipos_cliente (clase, tasa, num_prestamos, dias_max_prestamo)
    VALUES ("1", 10.5, 3, 3),("2", 15.0, 5, 5),("3", 25.0, 7, 15);
    """
ejecutor_sql(creacion_tabla)
ejecutor_sql(insercion_datos)

# %%
leer_tabla("Tipos_cliente")

# %% [markdown]
# ## Creación e inserción de datos en Clientes

# %%
sql_crea_tabla = """
-- Tabla Clientes
CREATE TABLE Clientes (
cliente_id INT AUTO_INCREMENT PRIMARY KEY,
nombre VARCHAR(100) NOT NULL,
apellidos VARCHAR(100) NOT NULL,
telefono VARCHAR(15),
dni VARCHAR(20) UNIQUE NOT NULL,
correo_e VARCHAR(100) NOT NULL,
direccion TEXT,
ciudad INT,
fecha_nacimiento DATE,
tipo_cliente INT,
password VARCHAR(255) NOT NULL,
FOREIGN KEY (ciudad) REFERENCES Ciudades(ciudad_id),
FOREIGN KEY (tipo_cliente) REFERENCES Tipos_cliente(tipo_cliente_id)
);"""
sql_inserta_datos = """INSERT INTO Clientes (nombre, apellidos, telefono, dni, correo_e, direccion, ciudad, fecha_nacimiento, tipo_cliente, password)
VALUES
('Carlos', 'García López', '123456789', '12345678A', 'carlos.garcia@example.com', 'Calle Mayor, 10', 1, '1985-06-15', 1, 'password123'),
('María', 'Fernández Ruiz', '987654321', '87654321B', 'maria.fernandez@example.com', 'Avenida del Sol, 22', 2, '1990-12-05', 2, 'securepassword'),
('Juan', 'Martínez Pérez', '555555555', '11223344C', 'juan.martinez@example.com', 'Plaza de España, 7', 3, '1982-03-28', 1, 'mypassword123'),
('Laura', 'Hernández Gómez', '444444444', '55667788D', 'laura.hernandez@example.com', 'Calle Luna, 15', 1, '1995-07-22', 3, 'laurapass'),
('Sergio', 'Jiménez Ortiz', '666777888', '66778899E', 'sergio.jimenez@example.com', 'Paseo de la Castellana, 30', 2, '1988-11-02', 1, 'sergiopass'),
('Ana', 'Díaz Morales', '777888999', '77889900F', 'ana.diaz@example.com', 'Calle Nueva, 18', 3, '1992-09-14', 2, 'anapass123'),
('Luis', 'Sánchez Torres', '888999000', '88990011G', 'luis.sanchez@example.com', 'Calle Real, 12', 1, '1987-02-19', 3, 'luissecure'),
('Marta', 'Romero Castro', '999000111', '99001122H', 'marta.romero@example.com', 'Camino del Río, 9', 2, '1993-05-06', 2, 'martapass2023'),
('Javier', 'López Vargas', '000111222', '00112233I', 'javier.lopez@example.com', 'Calle Jardines, 45', 3, '1980-08-11', 1, 'javiervault'),
('Elena', 'González Flores', '111222333', '11223344J', 'elena.gonzalez@example.com', 'Calle Princesa, 8', 1, '1998-04-30', 2, 'elenasecret');
"""
ejecutor_sql(sql_crea_tabla)
ejecutor_sql(sql_inserta_datos)

# %%
leer_tabla("Clientes")

# %% [markdown]
# ## Inserción de datos de Películas

# %% [markdown]
# ### Obtención de los datos

# %%
peliculas = pd.read_csv("https://github.com/LearnDataSci/articles/raw/refs/heads/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/IMDB-Movie-Data.csv")

# %%
peliculas.columns

# %%
years = [2014, 2015, 2016]
peliculas_nuevas = peliculas[peliculas['Year'].isin(years)]

# %%
peliculas_nuevas.reset_index(drop=True, inplace=True)

# %%
peliculas_nuevas.reset_index(drop=False, inplace=True)

# %%
peliculas_nuevas.rename(columns={'index': 'pelicula_id'}, inplace=True)

# %%
peliculas_nuevas

# %% [markdown]
# ### Primero necesito crear la tabla `Peliculas` en la base de datos

# %%
ejecutor_sql("""-- Tabla Peliculas
CREATE TABLE Peliculas (
pelicula_id INT AUTO_INCREMENT PRIMARY KEY,
titulo VARCHAR(255) NOT NULL,
anio YEAR,
duracion INT,
pais VARCHAR(100),
director VARCHAR(100),
nota DECIMAL(3, 1),
referencia VARCHAR(255),
enlace TEXT
);""")

# %% [markdown]
# La tabla está creada, pero vacía

# %%
leer_tabla("Peliculas")

# %% [markdown]
# Vamos a mejorar el ejecutor_sql para que admita parametros y devuelva datos al hacer SELECT

# %%
config = {
    'user': 'root',  # Usuario
    'password': 'sQGJOjroYvDHdacUUcfqgwnuYrsFqkbv',  # Contraseña
    'host': 'viaduct.proxy.rlwy.net',  # Host público de Railway
    'database': 'railway',  # Nombre de la base de datos
    'port': 17016  # Puerto público de Railway
}
def ejecutor_sql(codigo_sql, config, params=None, return_results=False):
    import mysql.connector
    import pandas as pd

    try:
        # Conectar a la base de datos
        connection = clase_mysql.connector.connect(**config)
        cursor = connection.cursor()

        # Ejecutar la consulta
        if params:
            cursor.execute(codigo_sql, params)  # Consulta parametrizada
        else:
            cursor.execute(codigo_sql)  # Consulta sin parámetros

        # Si es una consulta de selección y se solicitan resultados
        if return_results and codigo_sql.strip().upper().startswith("SELECT"):
            # Obtener los resultados
            results = cursor.fetchall()
            # Convertir a DataFrame de Pandas (opcional)
            columns = [col[0] for col in cursor.description]  # Obtener nombres de columnas
            df = pd.DataFrame(results, columns=columns)
            return df
        else:
            # Confirmar la transacción para consultas que no son SELECT
            connection.commit()
            print("✅ Ejecución correcta de SQL")

    except clase_mysql.connector.Error as e:
        print(f"❌ Error de MySQL: {e}")

    finally:
        if connection:
            cursor.close()
            connection.close()
            print("🔗 Conexión cerrada")

# %%
# Insertar datos de ciudades
def insertar_peliculas(values):
    insert_query = f"""INSERT INTO Peliculas (titulo, anio, duracion, pais, director, nota, referencia, enlace)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s);"""
    ejecutor_sql(insert_query, config, params = values)  # Es importante hacer commit para guardar los cambios
    print(f"{values[0]} insertado exitosamente")

# %%
peliculas_nuevas.columns

# %%
for index, row in peliculas_nuevas.iterrows():
    titulo = row['Title']
    anio = row['Year']
    duracion = row['Runtime (Minutes)']
    pais = "Desconocido"
    director = row['Director']
    nota = row['Rating']
    referencia = row['Description']
    enlace = row['Actors']
    values = (titulo, anio, duracion, pais, director, nota, referencia, enlace)
    insertar_peliculas(values)

# %%
leer_tabla("Peliculas")

# %%
tabla_peliculas = ejecutor_sql("SELECT * FROM Peliculas;", config, return_results=True)
tabla_peliculas

# %%
creacion_copias = """
CREATE TABLE Copias (
copia_id INT AUTO_INCREMENT PRIMARY KEY,
pelicula INT,
pasillo VARCHAR(20),
estanteria VARCHAR(20),
FOREIGN KEY (pelicula) REFERENCES Peliculas(pelicula_id)
);"""
insercion_copias = """
INSERT INTO Copias (pelicula, pasillo, estanteria)
VALUES
(1, '1', 'A'),
(2, '2', 'B'),
(3, '4', 'C'),
(3, '2', 'C'),
(2, '3', 'B'),
(5, '1', 'A'),
(6, '4', 'C'),
(7, '4', 'B'),
(8, '5', 'C'),
(6, '1', 'A');
"""
ejecutor_sql(creacion_copias, config)
ejecutor_sql(insercion_copias, config)

# %%
creacion_prestamos = """
-- Tabla Préstamos
CREATE TABLE Prestamos (
prestamo_id INT AUTO_INCREMENT PRIMARY KEY,
copia INT,
cliente INT,
fecha_prestamo DATE,
fecha_devolucion DATE,
FOREIGN KEY (copia) REFERENCES Copias(copia_id),
FOREIGN KEY (cliente) REFERENCES Clientes(cliente_id)
);
"""
insercion_prestamos = """INSERT INTO Prestamos (copia, cliente, fecha_prestamo, fecha_devolucion)
VALUES
(1, 1, '2025-01-01', '2025-01-15'),
(2, 2, '2025-01-05', '2025-01-20'),
(3, 3, '2025-01-10', NULL),
(4, 4, '2025-01-15', '2025-01-30'),
(5, 5, '2025-01-18', NULL),
(6, 6, '2025-01-20', '2025-02-01'),
(7, 7, '2025-01-25', '2025-02-05'),
(8, 8, '2025-01-27', NULL),
(9, 9, '2025-01-29', NULL),
(10, 10, '2025-01-30', NULL);"""
ejecutor_sql(creacion_prestamos, config)
ejecutor_sql(insercion_prestamos, config)

# %%
leer_tabla("Prestamos")
